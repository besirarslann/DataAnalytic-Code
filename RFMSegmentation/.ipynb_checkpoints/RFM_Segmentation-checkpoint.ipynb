# %% [markdown]
# # Data Understand for Online Retail

# %% [markdown]
# * # Customer Segmentation with RFM in 6 Steps
#
#  1. Business Problem
#  2. Data Understanding
#  3. Data Preparation
#  4. Calculating RFM Metrics
#  5. Calculating RFM Scores
#  6. Naming & Analysing RFM Segments

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import seaborn as sns
import pandas as pd
import datetime as dt
#pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df_ = pd.read_excel("online_retail_II.xlsx")

# %%
df = df_.copy()
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
def data_understand(dataframe):
    print("*************************** Data shape ***************************")
    print(dataframe.shape)
    print("*************************** Are there any missing values? ***************************")
    print(dataframe.isnull().sum())
    print("*************************** Data unique values ***************************")
    print(dataframe.describe())
    print("*************************** Description number of unique values ***************************")
    print(dataframe["Description"].nunique())
    print("*************************** Description value counts values first 10 columns ***************************")
    print(dataframe["Description"].value_counts().head(10))
    print("*************************** Description value counts values last 10 columns ***************************")
    print(dataframe["Description"].value_counts().tail(10))
    print("*************************** Invoice unique values ***************************")
    print(dataframe["Invoice"].nunique())
    print("*************************** Invoice value counts values ***************************")
    print(dataframe["Invoice"].value_counts().head(10))
data_understand(df)
# Out:
# *************************** Data shape ***************************
# (525461, 8)
# *************************** Are there any missing values? ***************************
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64
# *************************** Data unique values ***************************
#             Quantity          Price    Customer ID
# count  525461.000000  525461.000000  417534.000000
# mean       10.337667       4.688834   15360.645478
# std       107.424110     146.126914    1680.811316
# min     -9600.000000  -53594.360000   12346.000000
# 25%         1.000000       1.250000   13983.000000
# 50%         3.000000       2.100000   15311.000000
# 75%        10.000000       4.210000   16799.000000
# max     19152.000000   25111.090000   18287.000000
# *************************** Description number of unique values ***************************
# 4681
# *************************** Description value counts values first 10 columns ***************************
# WHITE HANGING HEART T-LIGHT HOLDER    3549
# REGENCY CAKESTAND 3 TIER              2212
# STRAWBERRY CERAMIC TRINKET BOX        1843
# PACK OF 72 RETRO SPOT CAKE CASES      1466
# ASSORTED COLOUR BIRD ORNAMENT         1457
# 60 TEATIME FAIRY CAKE CASES           1400
# HOME BUILDING BLOCK WORD              1386
# JUMBO BAG RED RETROSPOT               1310
# LUNCH BAG RED SPOTTY                  1274
# REX CASH+CARRY JUMBO SHOPPER          1232
# Name: Description, dtype: int64
# *************************** Description value counts values last 10 columns ***************************
# BAG FOR CHILDREN VINTAGE PINK          1
# BLUE OWL DECORATION                    1
# PINK OWL DECORATION                    1
# IVORY WALL CLOCK                       1
# RED WALL CLOCK                         1
# stock credited from royal yacht inc    1
# VINTAGE METAL CAKE STAND CREAM         1
# BLUE BAROQUE FLOCK CANDLE HOLDER       1
# S/4 HEART CRYSTAL FRIDGE MAGNETS       1
# dotcom email                           1
# Name: Description, dtype: int64
# *************************** Invoice unique values ***************************
# 28816
# *************************** Invoice value counts values ***************************
# 537434    675
# 538071    652
# 537638    601
# 537237    597
# 536876    593
# 536592    592
# 537823    591
# 536031    582
# 490074    580
# 491966    579
# Name: Invoice, dtype: int64

# %%
df.groupby(["Description"]).agg({"Quantity":"sum"}).head(5)
# Out:
#                                      Quantity
# Description
# 21494                                    -720
# 22467                                      -2
# 22719                                       2
#   DOORMAT UNION JACK GUNS AND ROSES       179
#  3 STRIPEY MICE FELTCRAFT                 690

# %%
df.loc[df["Invoice"] ==537434].head()
df.loc[df["Description"] ==21494]
# Out:
#        Invoice StockCode                Description  Quantity  \
# 516208  537434     20685      DOORMAT RED RETROSPOT         1
# 516209  537434     20699  MOUSEY LONG LEGS SOFT TOY         1
# 516210  537434     20713             JUMBO BAG OWLS         1
# 516211  537434     20719     WOODLAND CHARLOTTE BAG         3
# 516212  537434     20725    LUNCH BAG RED RETROSPOT         4
#
#                InvoiceDate  Price  Customer ID         Country
# 516208 2010-12-06 16:57:00  14.43          NaN  United Kingdom
# 516209 2010-12-06 16:57:00   5.06          NaN  United Kingdom
# 516210 2010-12-06 16:57:00   4.21          NaN  United Kingdom
# 516211 2010-12-06 16:57:00   1.66          NaN  United Kingdom
# 516212 2010-12-06 16:57:00   4.21          NaN  United Kingdom
#      Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 6911  490007     84347       21494      -720 2009-12-03 12:09:00    0.0
#
#       Customer ID         Country
# 6911          NaN  United Kingdom

# %%
# BURADA KARIŞIK İŞLER DÖNDÜ :))
df["Quantity"] = df["Quantity"].astype(dtype="string")
df.info()
df.loc[df["Quantity"].str.startswith("-", na=False)] # 12326 Quantity equals to negative values
df["Quantity"] = df["Quantity"].astype("int64")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  string
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(4), string(1)
# memory usage: 32.1+ MB
#         Invoice StockCode                    Description Quantity  \
# 178     C489449     22087       PAPER BUNTING WHITE LACE      -12
# 179     C489449    85206A   CREAM FELT EASTER EGG BASKET       -6
# 180     C489449     21895  POTTING SHED SOW 'N' GROW SET       -4
# 181     C489449     21896             POTTING SHED TWINE       -6
# 182     C489449     22083     PAPER CHAIN KIT RETRO SPOT      -12
# ...         ...       ...                            ...      ...
# 525231   538159     21324                            NaN      -18
# 525232   538158     20892                            NaN      -32
# 525234   538161    46000S                   Dotcom sales     -100
# 525235   538162    46000M                   Dotcom sales     -100
# 525282  C538164    35004B    SET OF 3 BLACK FLYING DUCKS       -1
#
#                InvoiceDate  Price  Customer ID         Country
# 178    2009-12-01 10:33:00   2.95      16321.0       Australia
# 179    2009-12-01 10:33:00   1.65      16321.0       Australia
# 180    2009-12-01 10:33:00   4.25      16321.0       Australia
# 181    2009-12-01 10:33:00   2.10      16321.0       Australia
# 182    2009-12-01 10:33:00   2.95      16321.0       Australia
# ...                    ...    ...          ...             ...
# 525231 2010-12-09 17:17:00   0.00          NaN  United Kingdom
# 525232 2010-12-09 17:17:00   0.00          NaN  United Kingdom
# 525234 2010-12-09 17:25:00   0.00          NaN  United Kingdom
# 525235 2010-12-09 17:25:00   0.00          NaN  United Kingdom
# 525282 2010-12-09 17:32:00   1.95      14031.0  United Kingdom
#
# [12326 rows x 8 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
# In Invoice column, it contains "C". "C" means cancel invoice the number of 10206 
df = df.loc[~df["Invoice"].str.contains("C", na=False)] # !!carreful!! if you dont put na=false, you encounter error

# %%
# Price multiply by Quantity = TotalPrice
df["TotalPrice"] = df["Price"] * df["Quantity"]

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  TotalPrice
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom        83.4
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.0
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.0
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom       100.8
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom        30.0

# %%
df.sort_values("Price",ascending=False).head()
# Out:
#        Invoice  StockCode Description  Quantity         InvoiceDate     Price  \
# 241827  512771          M      Manual         1 2010-06-17 16:53:00  25111.09
# 517955  537632  AMAZONFEE  AMAZON FEE         1 2010-12-07 15:08:00  13541.33
# 135013  502263          M      Manual         1 2010-03-23 15:22:00  10953.50
# 135015  502265          M      Manual         1 2010-03-23 15:28:00  10953.50
# 342147  522796          M      Manual         1 2010-09-16 15:12:00  10468.80
#
#         Customer ID         Country  TotalPrice
# 241827          NaN  United Kingdom    25111.09
# 517955          NaN  United Kingdom    13541.33
# 135013      12918.0  United Kingdom    10953.50
# 135015          NaN  United Kingdom    10953.50
# 342147          NaN  United Kingdom    10468.80

# %%
df.Country.value_counts().head(10)
# Out:
# United Kingdom    477058
# EIRE                9460
# Germany             7661
# France              5532
# Netherlands         2730
# Spain               1235
# Switzerland         1170
# Portugal            1061
# Belgium             1038
# Sweden               887
# Name: Country, dtype: int64

# %%
df_top10 = df.groupby("Country").agg({"TotalPrice": "sum"}).sort_values("TotalPrice", ascending=False)[1:12].reset_index() # without USA 
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot(x = "Country", y="TotalPrice", data=df_top10)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='TotalPrice'>

# %%
df_country = df["Country"].value_counts().reset_index()[1:12]
sns.barplot(x="index", y="Country", data=df_country)
# Out:
# <AxesSubplot:xlabel='index', ylabel='Country'>

# %% [markdown]
# # Data Preparation

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107560
# Country             0
# TotalPrice          0
# dtype: int64

# %%
# Drop missing values
def data_prep(dataframe):
    dataframe.dropna(inplace=True)
    return dataframe
df = data_prep(df)

# %%
df.shape
# Out:
# (407695, 9)

# %%
(525461 - 417534) / 525461
# Out:
# 0.20539488182757618

# %%
df.describe([0.01, 0.05, 0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]).T # Data has several outliers value
# Out:
#                 count          mean          std      min        1%        5%  \
# Quantity     407695.0     13.586686    96.842229      1.0      1.00      1.00
# Price        407695.0      3.294188    34.756655      0.0      0.29      0.42
# Customer ID  407695.0  15368.504107  1679.795700  12346.0  12435.00  12731.00
# TotalPrice   407695.0     21.663261    77.147356      0.0      0.65      1.25
#
#                   10%       25%       50%       75%       90%      95%  \
# Quantity         1.00      2.00      5.00     12.00     24.00     36.0
# Price            0.65      1.25      1.95      3.75      6.75      8.5
# Customer ID  13044.00  13997.00  15321.00  16812.00  17706.00  17913.0
# TotalPrice       2.10      4.95     11.90     19.50     35.70     67.5
#
#                   99%      max
# Quantity       144.00  19152.0
# Price           14.95  10953.5
# Customer ID  18196.00  18287.0
# TotalPrice     201.60  15818.4

# %% [markdown]
# # Calculating RFM Metrics
# * Recency, Frequency, Monetary
# * Today's date - Last purchase

# %%
df["Customer ID"] = df["Customer ID"].astype("int64") # Customer id format change to int64
df.sort_values("Customer ID", inplace=True)
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#   Invoice StockCode                 Description  Quantity         InvoiceDate  \
# 0  494450   TEST001     This is a test product.         5 2010-01-14 13:50:00
# 1  499763     20682  RED SPOTTY CHILDS UMBRELLA         1 2010-03-02 13:08:00
# 2  499763     20679       EDWARDIAN PARASOL RED         1 2010-03-02 13:08:00
# 3  499763    15056N   EDWARDIAN PARASOL NATURAL         1 2010-03-02 13:08:00
# 4  499763   15056BL     EDWARDIAN PARASOL BLACK         1 2010-03-02 13:08:00
#
#    Price  Customer ID         Country  TotalPrice
# 0   4.50        12346  United Kingdom       22.50
# 1   3.25        12346  United Kingdom        3.25
# 2   5.95        12346  United Kingdom        5.95
# 3   5.95        12346  United Kingdom        5.95
# 4   5.95        12346  United Kingdom        5.95

# %%
today_date = dt.datetime(2010, 12, 11, 20, 1)
print(today_date)
# Out:
# 2010-12-11 20:01:00

# %%
# Recency
df.groupby('Customer ID').agg({'InvoiceDate': lambda date: (today_date - date.max()).days})
# Out:
#              InvoiceDate
# Customer ID
# 12346                166
# 12347                  4
# 12348                 75
# 12349                 44
# 12351                 12
# ...                  ...
# 18283                 19
# 18284                 68
# 18285                297
# 18286                113
# 18287                 19
#
# [4314 rows x 1 columns]

# %%
# df["Recency"] = (today_date - df["InvoiceDate"]).astype('timedelta64[D]') - > Method 1
def create_recency(dataframe):
    dataframe["Recency"] = (today_date - dataframe["InvoiceDate"]).dt.days
    return dataframe
df = create_recency(df)

# %%
df.head()
# Out:
#   Invoice StockCode                 Description  Quantity         InvoiceDate  \
# 0  494450   TEST001     This is a test product.         5 2010-01-14 13:50:00
# 1  499763     20682  RED SPOTTY CHILDS UMBRELLA         1 2010-03-02 13:08:00
# 2  499763     20679       EDWARDIAN PARASOL RED         1 2010-03-02 13:08:00
# 3  499763    15056N   EDWARDIAN PARASOL NATURAL         1 2010-03-02 13:08:00
# 4  499763   15056BL     EDWARDIAN PARASOL BLACK         1 2010-03-02 13:08:00
#
#    Price  Customer ID         Country  TotalPrice  Recency
# 0   4.50        12346  United Kingdom       22.50      331
# 1   3.25        12346  United Kingdom        3.25      284
# 2   5.95        12346  United Kingdom        5.95      284
# 3   5.95        12346  United Kingdom        5.95      284
# 4   5.95        12346  United Kingdom        5.95      284

# %%
df_recencyRFM = df.groupby("Customer ID").agg({"Recency":"min"}).reset_index()
df_recencyRFM.head()
# Out:
#    Customer ID  Recency
# 0        12346      166
# 1        12347        4
# 2        12348       75
# 3        12349       44
# 4        12351       12

# %%
# total geşil ortalamalrına göre cutomerID groupby
df_customer_recencyMin = df.groupby("Customer ID").agg({"Recency":"min"}).sort_values("Recency").astype("int64").reset_index()[0:100]
df_customer_recencyMin
# Out:
#     Customer ID  Recency
# 0         17430        2
# 1         15271        2
# 2         13102        2
# 3         13090        2
# 4         15211        2
# ..          ...      ...
# 95        16016        3
# 96        16713        3
# 97        16722        3
# 98        16081        3
# 99        16011        3
#
# [100 rows x 2 columns]

# %%
# total geiliş ortalamalrına göre cutomerID groupby
df_customer_recencyMean = df.groupby("Customer ID").agg({"Recency":"mean"}).sort_values("Recency").astype("int64").reset_index()[0:40]
df_customer_recencyMean.head()
df_customer_recencyMean.Recency.max()
# Out:
#    Customer ID  Recency
# 0        15211        2
# 1        12942        2
# 2        13369        2
# 3        18043        3
# 4        12441        3
# 9

# %%
import matplotlib.pyplot as plt
ax = sns.barplot(x= "Customer ID", y= "Recency",
            data = df_customer_recencyMean)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show();

# %%
# Frequency
# Calculate Frequency önce Invoice No ve Customer ID duplicate et sonra count yap
df_freqRFM = df[["Invoice", "Customer ID" ]]
df_freqRFM.loc[40:48]
# Out:
#    Invoice  Customer ID
# 40  537626        12347
# 41  537626        12347
# 42  537626        12347
# 43  537626        12347
# 44  537626        12347
# 45  537626        12347
# 46  537626        12347
# 47  537626        12347
# 48  529924        12347

# %%
df_freqRFM = df_freqRFM.drop_duplicates(subset="Invoice").reset_index(drop=True)
df_freqRFM.head(16)
# Out:
#    Invoice  Customer ID
# 0   494450        12346
# 1   499763        12346
# 2   492722        12346
# 3   491744        12346
# 4   513774        12346
# 5   492718        12346
# 6   493412        12346
# 7   491725        12346
# 8   491742        12346
# 9   493410        12346
# 10  495295        12346
# 11  537626        12347
# 12  529924        12347
# 13  524140        12348
# 14  506394        12349
# 15  529344        12349

# %%
df_freqRFM= df_freqRFM.groupby("Customer ID").count().reset_index()
df_freqRFM.columns = ['Customer ID', 'Frequency']
df_freqRFM.head()
# Out:
#    Customer ID  Frequency
# 0        12346         11
# 1        12347          2
# 2        12348          1
# 3        12349          3
# 4        12351          1

# %%
# Monetary
df_monetaryRFM = df.groupby("Customer ID").agg({"TotalPrice":"sum"}).reset_index()
df_monetaryRFM.columns = ['Customer ID', 'Monetary']
df_monetaryRFM.head()
# Out:
#    Customer ID  Monetary
# 0        12346    372.86
# 1        12347   1323.32
# 2        12348    222.16
# 3        12349   2671.14
# 4        12351    300.93

# %%
df_recencyRFM.head()
df_recencyRFM.shape
df_freqRFM.head()
df_freqRFM.shape
df_monetaryRFM.head()
df_monetaryRFM.shape
# Out:
#    Customer ID  Recency
# 0        12346      166
# 1        12347        4
# 2        12348       75
# 3        12349       44
# 4        12351       12
# (4314, 2)
#    Customer ID  Frequency
# 0        12346         11
# 1        12347          2
# 2        12348          1
# 3        12349          3
# 4        12351          1
# (4314, 2)
#    Customer ID  Monetary
# 0        12346    372.86
# 1        12347   1323.32
# 2        12348    222.16
# 3        12349   2671.14
# 4        12351    300.93
# (4314, 2)

# %%
df_rf = pd.merge(df_recencyRFM, df_freqRFM, how="left", on=["Customer ID"])
df_rfm = pd.merge(df_rf, df_monetaryRFM, how="left", on=["Customer ID"])

# %%
df_rfm =df_rfm.set_index("Customer ID")

# %%
df_rfm.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4314 entries, 12346 to 18287
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Recency    4314 non-null   int64
#  1   Frequency  4314 non-null   int64
#  2   Monetary   4314 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 134.8 KB

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

st_scaler = StandardScaler()
st_scaled = st_scaler.fit_transform(df_rfm)

from sklearn.preprocessing import MinMaxScaler

mm_scaler = MinMaxScaler()
mm_scaled = mm_scaler.fit_transform(df_rfm)

# %%
st_scaled
mm_scaled
# Out:
# array([[ 0.76064344,  0.80143595, -0.18789547],
#        [-0.91062704, -0.30046398, -0.08123991],
#        [-0.17815665, -0.42289731, -0.20480622],
#        ...,
#        [ 2.1121029 , -0.42289731, -0.18182017],
#        [ 0.21386976, -0.30046398, -0.08425736],
#        [-0.75587978, -0.05559733,  0.03348725]])
# array([[4.39678284e-01, 4.90196078e-02, 1.06786389e-03],
#        [5.36193029e-03, 4.90196078e-03, 3.78996309e-03],
#        [1.95710456e-01, 0.00000000e+00, 6.36261978e-04],
#        ...,
#        [7.90884718e-01, 0.00000000e+00, 1.22291981e-03],
#        [2.97587131e-01, 4.90196078e-03, 3.71295065e-03],
#        [4.55764075e-02, 1.47058824e-02, 6.71806844e-03]])

# %% [markdown]
# # Cluster - Unsupervised Technique K-MEANS
# * we have to group the customers based on the Clusters
# * Elbow method a heuristic used in determining the number of clusters in a data set
# * Elbow method for selection of optimal "K" clusters
# * After the 3rd cluster point, the line is straight
# * Elbow falls in between 2 and 4, thats why we choose cluster of number is 3
# * One of the most widely used way to find number of class find the number of cluesters

# %%
from sklearn.cluster import KMeans

inertia = []
for i in np.arange(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(st_scaled)
    inertia.append(kmeans.inertia_)
plt.plot(inertia, marker="o");

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(st_scaled)
df_rfm["Clusters"] = (kmeans.labels_ +1)
# Out:
# KMeans(n_clusters=3)

# %%
df_rfm
# Out:
#              Recency  Frequency  Monetary  Clusters
# Customer ID
# 12346            166         11    372.86         2
# 12347              4          2   1323.32         1
# 12348             75          1    222.16         1
# 12349             44          3   2671.14         1
# 12351             12          1    300.93         1
# ...              ...        ...       ...       ...
# 18283             19          6    641.77         1
# 18284             68          1    461.68         1
# 18285            297          1    427.00         2
# 18286            113          2   1296.43         1
# 18287             19          4   2345.71         1
#
# [4314 rows x 4 columns]

# %%
df_rfm.groupby(["Clusters"])["Recency", "Frequency", "Monetary"].mean()
# Out:
# C:\Users\besir\AppData\Local\Temp\ipykernel_5404\414398233.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_rfm.groupby(["Clusters"])["Recency", "Frequency", "Monetary"].mean()
#              Recency   Frequency       Monetary
# Clusters
# 1          43.264279    4.942575    2082.315956
# 2         242.794727    1.653484     592.900974
# 3           5.230769  111.538462  112132.389231

# %%
def func(row):
    if row["Clusters"] ==1:
        return "Avg.CX"
    if row["Clusters"] ==2:
        return "Whales"
    else:
        return "Lapsed.CX"

df_rfm["Conditions"] = df_rfm.apply(func, axis=1)

# %%
result = df_rfm["Conditions"].value_counts()
result
# Out:
# Avg.CX       3239
# Whales       1062
# Lapsed.CX      13
# Name: Conditions, dtype: int64

# %%
result.plot(kind="barh", color= ["blue", "green", "red"])
# Out:
# <AxesSubplot:>

# %%
df_rfm.reset_index().to_excel("RFM_SegmentKMeans.xlsx")
